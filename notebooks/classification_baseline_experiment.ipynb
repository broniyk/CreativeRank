# %% [markdown]
# ### Data Preparation

# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))
# %load_ext autoreload
# %autoreload 2

import os 
import mlflow
import pandas as pd
import numpy as np
from catboost import cv
from experiment_data import get_experiment_data, split_experiment_train_test_val_data, CATEGORICAL_COLS, COLS
from models import get_pooled_dataset, get_catboost_classifier
from metrics import mrr_at_k_per_experiment, hit_rate_at_k_per_experiment, bootstrap_mrr_at_k
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = get_experiment_data()
# Out:
# users_df size before removing small experiments: 501008 rows
# users_df size after removing small experiments: 500953 rows

# %%
train_data, _, test_data = split_experiment_train_test_val_data(data, n_last_test=4, n_last_val=0)
train_data = train_data.query("CLICK==1 or CLICK==0")
# Subsample to include all recipients with click=1, and equal number from click=0


train_df, train_pool, _, train_X, train_y = get_pooled_dataset(train_data, COLS, CATEGORICAL_COLS, pos_neg_ratio=1)
test_df, test_pool, _, test_X, test_y = get_pooled_dataset(test_data, COLS, CATEGORICAL_COLS)


model_params = {
    'iterations': 50,
    'learning_rate': 0.05,
    'eval_metric': 'AUC',
    'early_stopping_rounds': 20,
    'loss_function': 'Logloss',
    'random_seed': 42,
    'verbose': False
}

mlflow.set_experiment("Pointwise Ranking: Classification")

with mlflow.start_run(run_name="test_run") as run:
    cv_results = cv(
        params=model_params,
        pool=train_pool,
        fold_count=5,
        shuffle=True,
        partition_random_seed=42,
        verbose=True,
        stratified=False,
        early_stopping_rounds=20,
        as_pandas=True
    )

    best_iter = cv_results['test-AUC-mean'].idxmax()
    best_auc = cv_results.loc[best_iter, 'test-AUC-mean']

    mlflow.log_param("best_iteration", int(best_iter))
    mlflow.log_metric("best_cv_auc", float(best_auc))

    test_df, test_pool, _, test_X, test_y = get_pooled_dataset(test_data, COLS, CATEGORICAL_COLS)
    # Train CatBoostClassifier with best number of iterations found in CV

    model_params.update(iterations=best_iter)
    model = get_catboost_classifier(
        CATEGORICAL_COLS,
        model_params,
    )

    model.fit(train_pool)


    # Predict probability for the test set (probability that CLICK=1)
    scores = model.predict_proba(test_pool)[:, 1]
    preds = test_df.assign(PRED=scores)[["EXPERIMENT_ID", "RECIPIENT_ID", "VARIATION_ID", "PRED"]]
    y_true = test_df[["EXPERIMENT_ID", "RECIPIENT_ID", "VARIATION_ID", "CLICK"]].query("CLICK==1") 

    mrr_at_k_per_experiment(preds, y_true, 5, prefix="test_")
    hit_rate_at_k_per_experiment(preds, y_true, 1, prefix="test_")
    bootstrap_mrr_at_k(preds, y_true, 5, bootstrap_samples=100, random_state=42, prefix="test_")

    print(f"Best mean AUC across 5 folds: {best_auc:.4f} at iteration {best_iter}")
# Out:
# Training on fold [0/5]
# 0:	test: 0.5706248	best: 0.5706248 (0)	total: 33.2ms	remaining: 1.63s
# 1:	test: 0.5786835	best: 0.5786835 (1)	total: 59.3ms	remaining: 1.42s
# 2:	test: 0.5814499	best: 0.5814499 (2)	total: 88.2ms	remaining: 1.38s
# 3:	test: 0.5849329	best: 0.5849329 (3)	total: 117ms	remaining: 1.34s
# 4:	test: 0.5896289	best: 0.5896289 (4)	total: 146ms	remaining: 1.31s
# 5:	test: 0.5890622	best: 0.5896289 (4)	total: 174ms	remaining: 1.28s
# 6:	test: 0.5903551	best: 0.5903551 (6)	total: 204ms	remaining: 1.25s
# 7:	test: 0.5904940	best: 0.5904940 (7)	total: 234ms	remaining: 1.23s
# 8:	test: 0.5896802	best: 0.5904940 (7)	total: 258ms	remaining: 1.17s
# 9:	test: 0.5895720	best: 0.5904940 (7)	total: 290ms	remaining: 1.16s
# 10:	test: 0.5898872	best: 0.5904940 (7)	total: 316ms	remaining: 1.12s
# 11:	test: 0.5896066	best: 0.5904940 (7)	total: 343ms	remaining: 1.09s
# 12:	test: 0.5893384	best: 0.5904940 (7)	total: 372ms	remaining: 1.06s
# 13:	test: 0.5893409	best: 0.5904940 (7)	total: 387ms	remaining: 996ms
# 14:	test: 0.5896336	best: 0.5904940 (7)	total: 419ms	remaining: 978ms
# 15:	test: 0.5941575	best: 0.5941575 (15)	total: 447ms	remaining: 951ms
# 16:	test: 0.5940988	best: 0.5941575 (15)	total: 478ms	remaining: 929ms
# 17:	test: 0.5942749	best: 0.5942749 (17)	total: 505ms	remaining: 898ms
# 18:	test: 0.5939994	best: 0.5942749 (17)	total: 533ms	remaining: 869ms
# 19:	test: 0.5944242	best: 0.5944242 (19)	total: 563ms	remaining: 845ms
# 20:	test: 0.5956857	best: 0.5956857 (20)	total: 597ms	remaining: 824ms
# 21:	test: 0.5965219	best: 0.5965219 (21)	total: 625ms	remaining: 796ms
# 22:	test: 0.5977758	best: 0.5977758 (22)	total: 652ms	remaining: 765ms
# 23:	test: 0.5987250	best: 0.5987250 (23)	total: 678ms	remaining: 734ms
# 24:	test: 0.6000245	best: 0.6000245 (24)	total: 704ms	remaining: 704ms
# 25:	test: 0.6034849	best: 0.6034849 (25)	total: 730ms	remaining: 674ms
# 26:	test: 0.6071587	best: 0.6071587 (26)	total: 753ms	remaining: 641ms
# 27:	test: 0.6092958	best: 0.6092958 (27)	total: 783ms	remaining: 615ms
# 28:	test: 0.6112278	best: 0.6112278 (28)	total: 811ms	remaining: 587ms
# 29:	test: 0.6129686	best: 0.6129686 (29)	total: 838ms	remaining: 559ms
# 30:	test: 0.6144486	best: 0.6144486 (30)	total: 864ms	remaining: 530ms
# 31:	test: 0.6152999	best: 0.6152999 (31)	total: 891ms	remaining: 501ms
# 32:	test: 0.6163235	best: 0.6163235 (32)	total: 918ms	remaining: 473ms
# 33:	test: 0.6171189	best: 0.6171189 (33)	total: 946ms	remaining: 445ms
# 34:	test: 0.6190095	best: 0.6190095 (34)	total: 972ms	remaining: 416ms
# 35:	test: 0.6199993	best: 0.6199993 (35)	total: 1s	remaining: 389ms
# 36:	test: 0.6201757	best: 0.6201757 (36)	total: 1.03s	remaining: 361ms
# 37:	test: 0.6205683	best: 0.6205683 (37)	total: 1.06s	remaining: 334ms
# 38:	test: 0.6203228	best: 0.6205683 (37)	total: 1.08s	remaining: 306ms
# 39:	test: 0.6209538	best: 0.6209538 (39)	total: 1.11s	remaining: 277ms
# 40:	test: 0.6225593	best: 0.6225593 (40)	total: 1.14s	remaining: 249ms
# 41:	test: 0.6235096	best: 0.6235096 (41)	total: 1.16s	remaining: 221ms
# 42:	test: 0.6235963	best: 0.6235963 (42)	total: 1.19s	remaining: 194ms
# 43:	test: 0.6238856	best: 0.6238856 (43)	total: 1.25s	remaining: 171ms
# 44:	test: 0.6246310	best: 0.6246310 (44)	total: 1.3s	remaining: 144ms
# 45:	test: 0.6244732	best: 0.6246310 (44)	total: 1.34s	remaining: 116ms
# 46:	test: 0.6267078	best: 0.6267078 (46)	total: 1.38s	remaining: 87.8ms
# 47:	test: 0.6293848	best: 0.6293848 (47)	total: 1.41s	remaining: 58.7ms
# 48:	test: 0.6296195	best: 0.6296195 (48)	total: 1.44s	remaining: 29.4ms
# 49:	test: 0.6302040	best: 0.6302040 (49)	total: 1.48s	remaining: 0us
#
# bestTest = 0.6302039843
# bestIteration = 49
#
# Training on fold [1/5]
# 0:	test: 0.5805351	best: 0.5805351 (0)	total: 41.1ms	remaining: 2.01s
# 1:	test: 0.5856667	best: 0.5856667 (1)	total: 70ms	remaining: 1.68s
# 2:	test: 0.5921491	best: 0.5921491 (2)	total: 101ms	remaining: 1.58s
# 3:	test: 0.5920795	best: 0.5921491 (2)	total: 131ms	remaining: 1.5s
# 4:	test: 0.6004196	best: 0.6004196 (4)	total: 158ms	remaining: 1.43s
# 5:	test: 0.5983102	best: 0.6004196 (4)	total: 189ms	remaining: 1.38s
# 6:	test: 0.5977296	best: 0.6004196 (4)	total: 216ms	remaining: 1.33s
# 7:	test: 0.5972833	best: 0.6004196 (4)	total: 246ms	remaining: 1.29s
# 8:	test: 0.5998782	best: 0.6004196 (4)	total: 279ms	remaining: 1.27s
# 9:	test: 0.6017209	best: 0.6017209 (9)	total: 314ms	remaining: 1.25s
# 10:	test: 0.6033029	best: 0.6033029 (10)	total: 351ms	remaining: 1.24s
# 11:	test: 0.6036154	best: 0.6036154 (11)	total: 388ms	remaining: 1.23s
# 12:	test: 0.6038442	best: 0.6038442 (12)	total: 418ms	remaining: 1.19s
# 13:	test: 0.6040514	best: 0.6040514 (13)	total: 447ms	remaining: 1.15s
# 14:	test: 0.6052981	best: 0.6052981 (14)	total: 476ms	remaining: 1.11s
# 15:	test: 0.6046380	best: 0.6052981 (14)	total: 502ms	remaining: 1.07s
# 16:	test: 0.6048911	best: 0.6052981 (14)	total: 531ms	remaining: 1.03s
# 17:	test: 0.6088080	best: 0.6088080 (17)	total: 562ms	remaining: 999ms
# 18:	test: 0.6086894	best: 0.6088080 (17)	total: 584ms	remaining: 954ms
# 19:	test: 0.6093058	best: 0.6093058 (19)	total: 615ms	remaining: 922ms
# 20:	test: 0.6106190	best: 0.6106190 (20)	total: 644ms	remaining: 890ms
# 21:	test: 0.6107241	best: 0.6107241 (21)	total: 670ms	remaining: 853ms
# 22:	test: 0.6179848	best: 0.6179848 (22)	total: 693ms	remaining: 814ms
# 23:	test: 0.6204503	best: 0.6204503 (23)	total: 717ms	remaining: 777ms
# 24:	test: 0.6204537	best: 0.6204537 (24)	total: 747ms	remaining: 747ms
# 25:	test: 0.6230547	best: 0.6230547 (25)	total: 774ms	remaining: 715ms
# 26:	test: 0.6229205	best: 0.6230547 (25)	total: 803ms	remaining: 684ms
# 27:	test: 0.6224875	best: 0.6230547 (25)	total: 831ms	remaining: 653ms
# 28:	test: 0.6233055	best: 0.6233055 (28)	total: 861ms	remaining: 623ms
# 29:	test: 0.6245785	best: 0.6245785 (29)	total: 887ms	remaining: 592ms
# 30:	test: 0.6245643	best: 0.6245785 (29)	total: 913ms	remaining: 559ms
# 31:	test: 0.6245401	best: 0.6245785 (29)	total: 938ms	remaining: 528ms
# 32:	test: 0.6273480	best: 0.6273480 (32)	total: 969ms	remaining: 499ms
# 33:	test: 0.6297281	best: 0.6297281 (33)	total: 994ms	remaining: 468ms
# 34:	test: 0.6316060	best: 0.6316060 (34)	total: 1.02s	remaining: 436ms
# 35:	test: 0.6332040	best: 0.6332040 (35)	total: 1.05s	remaining: 408ms
# 36:	test: 0.6348695	best: 0.6348695 (36)	total: 1.07s	remaining: 378ms
# 37:	test: 0.6359421	best: 0.6359421 (37)	total: 1.09s	remaining: 344ms
# 38:	test: 0.6356283	best: 0.6359421 (37)	total: 1.11s	remaining: 315ms
# 39:	test: 0.6367569	best: 0.6367569 (39)	total: 1.14s	remaining: 286ms
# 40:	test: 0.6371762	best: 0.6371762 (40)	total: 1.17s	remaining: 256ms
# 41:	test: 0.6393041	best: 0.6393041 (41)	total: 1.26s	remaining: 241ms
# 42:	test: 0.6397260	best: 0.6397260 (42)	total: 1.31s	remaining: 213ms
# 43:	test: 0.6393055	best: 0.6397260 (42)	total: 1.34s	remaining: 183ms
# 44:	test: 0.6391224	best: 0.6397260 (42)	total: 1.37s	remaining: 152ms
# 45:	test: 0.6396916	best: 0.6397260 (42)	total: 1.4s	remaining: 122ms
# 46:	test: 0.6406929	best: 0.6406929 (46)	total: 1.43s	remaining: 91.4ms
# 47:	test: 0.6408388	best: 0.6408388 (47)	total: 1.49s	remaining: 61.9ms
# 48:	test: 0.6439784	best: 0.6439784 (48)	total: 1.52s	remaining: 31ms
# 49:	test: 0.6447801	best: 0.6447801 (49)	total: 1.55s	remaining: 0us
#
# bestTest = 0.6447801461
# bestIteration = 49
#
# Training on fold [2/5]
# 0:	test: 0.5830088	best: 0.5830088 (0)	total: 48.6ms	remaining: 2.38s
# 1:	test: 0.5829233	best: 0.5830088 (0)	total: 122ms	remaining: 2.92s
# 2:	test: 0.5866405	best: 0.5866405 (2)	total: 160ms	remaining: 2.51s
# 3:	test: 0.5895706	best: 0.5895706 (3)	total: 190ms	remaining: 2.18s
# 4:	test: 0.5916885	best: 0.5916885 (4)	total: 213ms	remaining: 1.92s
# 5:	test: 0.5923884	best: 0.5923884 (5)	total: 247ms	remaining: 1.81s
# 6:	test: 0.5918784	best: 0.5923884 (5)	total: 279ms	remaining: 1.71s
# 7:	test: 0.5951443	best: 0.5951443 (7)	total: 308ms	remaining: 1.61s
# 8:	test: 0.5960358	best: 0.5960358 (8)	total: 339ms	remaining: 1.55s
# 9:	test: 0.5953635	best: 0.5960358 (8)	total: 373ms	remaining: 1.49s
# 10:	test: 0.5957550	best: 0.5960358 (8)	total: 406ms	remaining: 1.44s
# 11:	test: 0.5959478	best: 0.5960358 (8)	total: 436ms	remaining: 1.38s
# 12:	test: 0.5955742	best: 0.5960358 (8)	total: 470ms	remaining: 1.34s
# 13:	test: 0.5948731	best: 0.5960358 (8)	total: 497ms	remaining: 1.28s
# 14:	test: 0.5960354	best: 0.5960358 (8)	total: 525ms	remaining: 1.23s
# 15:	test: 0.5959137	best: 0.5960358 (8)	total: 554ms	remaining: 1.18s
# 16:	test: 0.5987292	best: 0.5987292 (16)	total: 581ms	remaining: 1.13s
# 17:	test: 0.5986300	best: 0.5987292 (16)	total: 608ms	remaining: 1.08s
# 18:	test: 0.5987926	best: 0.5987926 (18)	total: 638ms	remaining: 1.04s
# 19:	test: 0.5991165	best: 0.5991165 (19)	total: 664ms	remaining: 995ms
# 20:	test: 0.6025475	best: 0.6025475 (20)	total: 691ms	remaining: 954ms
# 21:	test: 0.6027696	best: 0.6027696 (21)	total: 719ms	remaining: 915ms
# 22:	test: 0.6082864	best: 0.6082864 (22)	total: 746ms	remaining: 876ms
# 23:	test: 0.6116928	best: 0.6116928 (23)	total: 779ms	remaining: 844ms
# 24:	test: 0.6144442	best: 0.6144442 (24)	total: 802ms	remaining: 802ms
# 25:	test: 0.6177844	best: 0.6177844 (25)	total: 829ms	remaining: 765ms
# 26:	test: 0.6197456	best: 0.6197456 (26)	total: 858ms	remaining: 731ms
# 27:	test: 0.6218419	best: 0.6218419 (27)	total: 886ms	remaining: 696ms
# 28:	test: 0.6231372	best: 0.6231372 (28)	total: 912ms	remaining: 660ms
# 29:	test: 0.6246845	best: 0.6246845 (29)	total: 940ms	remaining: 627ms
# 30:	test: 0.6261625	best: 0.6261625 (30)	total: 967ms	remaining: 592ms
# 31:	test: 0.6280349	best: 0.6280349 (31)	total: 991ms	remaining: 557ms
# 32:	test: 0.6293203	best: 0.6293203 (32)	total: 1.02s	remaining: 524ms
# 33:	test: 0.6353979	best: 0.6353979 (33)	total: 1.06s	remaining: 498ms
# 34:	test: 0.6363998	best: 0.6363998 (34)	total: 1.08s	remaining: 464ms
# 35:	test: 0.6364271	best: 0.6364271 (35)	total: 1.11s	remaining: 431ms
# 36:	test: 0.6381271	best: 0.6381271 (36)	total: 1.14s	remaining: 401ms
# 37:	test: 0.6386431	best: 0.6386431 (37)	total: 1.17s	remaining: 370ms
# 38:	test: 0.6396269	best: 0.6396269 (38)	total: 1.2s	remaining: 338ms
# 39:	test: 0.6412343	best: 0.6412343 (39)	total: 1.24s	remaining: 309ms
# 40:	test: 0.6417571	best: 0.6417571 (40)	total: 1.27s	remaining: 278ms
# 41:	test: 0.6422337	best: 0.6422337 (41)	total: 1.32s	remaining: 252ms
# 42:	test: 0.6439765	best: 0.6439765 (42)	total: 1.36s	remaining: 221ms
# 43:	test: 0.6448487	best: 0.6448487 (43)	total: 1.4s	remaining: 191ms
# 44:	test: 0.6453603	best: 0.6453603 (44)	total: 1.44s	remaining: 160ms
# 45:	test: 0.6452455	best: 0.6453603 (44)	total: 1.47s	remaining: 128ms
# 46:	test: 0.6455113	best: 0.6455113 (46)	total: 1.5s	remaining: 96ms
# 47:	test: 0.6456734	best: 0.6456734 (47)	total: 1.53s	remaining: 63.9ms
# 48:	test: 0.6472775	best: 0.6472775 (48)	total: 1.56s	remaining: 31.9ms
# 49:	test: 0.6474167	best: 0.6474167 (49)	total: 1.59s	remaining: 0us
#
# bestTest = 0.647416666
# bestIteration = 49
#
# Training on fold [3/5]
# 0:	test: 0.5820427	best: 0.5820427 (0)	total: 33.1ms	remaining: 1.62s
# 1:	test: 0.5872400	best: 0.5872400 (1)	total: 62.1ms	remaining: 1.49s
# 2:	test: 0.5866015	best: 0.5872400 (1)	total: 95.8ms	remaining: 1.5s
# 3:	test: 0.5945255	best: 0.5945255 (3)	total: 127ms	remaining: 1.46s
# 4:	test: 0.5934232	best: 0.5945255 (3)	total: 158ms	remaining: 1.42s
# 5:	test: 0.5930298	best: 0.5945255 (3)	total: 194ms	remaining: 1.42s
# 6:	test: 0.5937769	best: 0.5945255 (3)	total: 224ms	remaining: 1.38s
# 7:	test: 0.5935643	best: 0.5945255 (3)	total: 258ms	remaining: 1.36s
# 8:	test: 0.5947170	best: 0.5947170 (8)	total: 294ms	remaining: 1.34s
# 9:	test: 0.5961984	best: 0.5961984 (9)	total: 331ms	remaining: 1.32s
# 10:	test: 0.5956754	best: 0.5961984 (9)	total: 366ms	remaining: 1.3s
# 11:	test: 0.5957453	best: 0.5961984 (9)	total: 397ms	remaining: 1.26s
# 12:	test: 0.5956900	best: 0.5961984 (9)	total: 433ms	remaining: 1.23s
# 13:	test: 0.5967531	best: 0.5967531 (13)	total: 466ms	remaining: 1.2s
# 14:	test: 0.5994125	best: 0.5994125 (14)	total: 501ms	remaining: 1.17s
# 15:	test: 0.6052058	best: 0.6052058 (15)	total: 533ms	remaining: 1.13s
# 16:	test: 0.6055532	best: 0.6055532 (16)	total: 565ms	remaining: 1.1s
# 17:	test: 0.6062748	best: 0.6062748 (17)	total: 597ms	remaining: 1.06s
# 18:	test: 0.6119031	best: 0.6119031 (18)	total: 627ms	remaining: 1.02s
# 19:	test: 0.6117126	best: 0.6119031 (18)	total: 655ms	remaining: 983ms
# 20:	test: 0.6109726	best: 0.6119031 (18)	total: 685ms	remaining: 945ms
# 21:	test: 0.6109310	best: 0.6119031 (18)	total: 720ms	remaining: 916ms
# 22:	test: 0.6150158	best: 0.6150158 (22)	total: 749ms	remaining: 879ms
# 23:	test: 0.6186185	best: 0.6186185 (23)	total: 778ms	remaining: 843ms
# 24:	test: 0.6212386	best: 0.6212386 (24)	total: 803ms	remaining: 803ms
# 25:	test: 0.6235771	best: 0.6235771 (25)	total: 832ms	remaining: 768ms
# 26:	test: 0.6242590	best: 0.6242590 (26)	total: 859ms	remaining: 731ms
# 27:	test: 0.6252692	best: 0.6252692 (27)	total: 886ms	remaining: 696ms
# 28:	test: 0.6276183	best: 0.6276183 (28)	total: 917ms	remaining: 664ms
# 29:	test: 0.6283312	best: 0.6283312 (29)	total: 947ms	remaining: 632ms
# 30:	test: 0.6285753	best: 0.6285753 (30)	total: 979ms	remaining: 600ms
# 31:	test: 0.6292585	best: 0.6292585 (31)	total: 1.01s	remaining: 567ms
# 32:	test: 0.6297006	best: 0.6297006 (32)	total: 1.03s	remaining: 532ms
# 33:	test: 0.6302033	best: 0.6302033 (33)	total: 1.06s	remaining: 499ms
# 34:	test: 0.6312435	best: 0.6312435 (34)	total: 1.09s	remaining: 467ms
# 35:	test: 0.6319168	best: 0.6319168 (35)	total: 1.12s	remaining: 435ms
# 36:	test: 0.6319356	best: 0.6319356 (36)	total: 1.15s	remaining: 403ms
# 37:	test: 0.6324393	best: 0.6324393 (37)	total: 1.17s	remaining: 370ms
# 38:	test: 0.6348461	best: 0.6348461 (38)	total: 1.2s	remaining: 338ms
# 39:	test: 0.6350636	best: 0.6350636 (39)	total: 1.23s	remaining: 307ms
# 40:	test: 0.6348258	best: 0.6350636 (39)	total: 1.25s	remaining: 275ms
# 41:	test: 0.6351053	best: 0.6351053 (41)	total: 1.28s	remaining: 244ms
# 42:	test: 0.6359552	best: 0.6359552 (42)	total: 1.31s	remaining: 214ms
# 43:	test: 0.6362579	best: 0.6362579 (43)	total: 1.34s	remaining: 183ms
# 44:	test: 0.6372375	best: 0.6372375 (44)	total: 1.37s	remaining: 152ms
# 45:	test: 0.6371864	best: 0.6372375 (44)	total: 1.4s	remaining: 122ms
# 46:	test: 0.6371139	best: 0.6372375 (44)	total: 1.43s	remaining: 91.2ms
# 47:	test: 0.6369782	best: 0.6372375 (44)	total: 1.46s	remaining: 60.9ms
# 48:	test: 0.6376075	best: 0.6376075 (48)	total: 1.49s	remaining: 30.4ms
# 49:	test: 0.6382422	best: 0.6382422 (49)	total: 1.51s	remaining: 0us
#
# bestTest = 0.6382421704
# bestIteration = 49
#
# Training on fold [4/5]
# 0:	test: 0.5558702	best: 0.5558702 (0)	total: 37.3ms	remaining: 1.83s
# 1:	test: 0.5719516	best: 0.5719516 (1)	total: 70.4ms	remaining: 1.69s
# 2:	test: 0.5721494	best: 0.5721494 (2)	total: 99.1ms	remaining: 1.55s
# 3:	test: 0.5779446	best: 0.5779446 (3)	total: 127ms	remaining: 1.46s
# 4:	test: 0.5799676	best: 0.5799676 (4)	total: 167ms	remaining: 1.5s
# 5:	test: 0.5792129	best: 0.5799676 (4)	total: 195ms	remaining: 1.43s
# 6:	test: 0.5810522	best: 0.5810522 (6)	total: 224ms	remaining: 1.37s
# 7:	test: 0.5862403	best: 0.5862403 (7)	total: 252ms	remaining: 1.32s
# 8:	test: 0.5874518	best: 0.5874518 (8)	total: 279ms	remaining: 1.27s
# 9:	test: 0.5876626	best: 0.5876626 (9)	total: 307ms	remaining: 1.23s
# 10:	test: 0.5881799	best: 0.5881799 (10)	total: 336ms	remaining: 1.19s
# 11:	test: 0.5937196	best: 0.5937196 (11)	total: 370ms	remaining: 1.17s
# 12:	test: 0.5954991	best: 0.5954991 (12)	total: 401ms	remaining: 1.14s
# 13:	test: 0.5952319	best: 0.5954991 (12)	total: 428ms	remaining: 1.1s
# 14:	test: 0.5950831	best: 0.5954991 (12)	total: 455ms	remaining: 1.06s
# 15:	test: 0.5960129	best: 0.5960129 (15)	total: 481ms	remaining: 1.02s
# 16:	test: 0.5970734	best: 0.5970734 (16)	total: 507ms	remaining: 984ms
# 17:	test: 0.5993063	best: 0.5993063 (17)	total: 536ms	remaining: 953ms
# 18:	test: 0.5993175	best: 0.5993175 (18)	total: 557ms	remaining: 908ms
# 19:	test: 0.6006703	best: 0.6006703 (19)	total: 586ms	remaining: 879ms
# 20:	test: 0.6013500	best: 0.6013500 (20)	total: 613ms	remaining: 847ms
# 21:	test: 0.6017308	best: 0.6017308 (21)	total: 641ms	remaining: 816ms
# 22:	test: 0.6050895	best: 0.6050895 (22)	total: 665ms	remaining: 781ms
# 23:	test: 0.6083072	best: 0.6083072 (23)	total: 691ms	remaining: 749ms
# 24:	test: 0.6109143	best: 0.6109143 (24)	total: 718ms	remaining: 718ms
# 25:	test: 0.6130459	best: 0.6130459 (25)	total: 740ms	remaining: 683ms
# 26:	test: 0.6147698	best: 0.6147698 (26)	total: 766ms	remaining: 652ms
# 27:	test: 0.6149975	best: 0.6149975 (27)	total: 794ms	remaining: 624ms
# 28:	test: 0.6161991	best: 0.6161991 (28)	total: 823ms	remaining: 596ms
# 29:	test: 0.6162120	best: 0.6162120 (29)	total: 854ms	remaining: 569ms
# 30:	test: 0.6171661	best: 0.6171661 (30)	total: 885ms	remaining: 542ms
# 31:	test: 0.6184389	best: 0.6184389 (31)	total: 913ms	remaining: 514ms
# 32:	test: 0.6196235	best: 0.6196235 (32)	total: 944ms	remaining: 486ms
# 33:	test: 0.6208770	best: 0.6208770 (33)	total: 971ms	remaining: 457ms
# 34:	test: 0.6220666	best: 0.6220666 (34)	total: 999ms	remaining: 428ms
# 35:	test: 0.6232278	best: 0.6232278 (35)	total: 1.03s	remaining: 401ms
# 36:	test: 0.6244368	best: 0.6244368 (36)	total: 1.06s	remaining: 372ms
# 37:	test: 0.6246251	best: 0.6246251 (37)	total: 1.09s	remaining: 343ms
# 38:	test: 0.6249840	best: 0.6249840 (38)	total: 1.11s	remaining: 315ms
# 39:	test: 0.6256394	best: 0.6256394 (39)	total: 1.15s	remaining: 287ms
# 40:	test: 0.6267307	best: 0.6267307 (40)	total: 1.18s	remaining: 258ms
# 41:	test: 0.6275920	best: 0.6275920 (41)	total: 1.2s	remaining: 229ms
# 42:	test: 0.6280904	best: 0.6280904 (42)	total: 1.24s	remaining: 201ms
# 43:	test: 0.6282798	best: 0.6282798 (43)	total: 1.26s	remaining: 173ms
# 44:	test: 0.6288228	best: 0.6288228 (44)	total: 1.29s	remaining: 144ms
# 45:	test: 0.6287638	best: 0.6288228 (44)	total: 1.32s	remaining: 115ms
# 46:	test: 0.6289652	best: 0.6289652 (46)	total: 1.35s	remaining: 86ms
# 47:	test: 0.6297875	best: 0.6297875 (47)	total: 1.38s	remaining: 57.4ms
# 48:	test: 0.6303531	best: 0.6303531 (48)	total: 1.41s	remaining: 28.7ms
# 49:	test: 0.6301662	best: 0.6303531 (48)	total: 1.44s	remaining: 0us
#
# bestTest = 0.630353092
# bestIteration = 48
#
# Best mean AUC across 5 folds: 0.6382 at iteration 49
