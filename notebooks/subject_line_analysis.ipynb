# %%
import sys
import pandas as pd
sys.path.append('/Users/broniy/Desktop/creative')
# %load_ext autoreload
# %autoreload 2

# %%
sbl_df = pd.read_csv("../data/subject_lines.csv")
sbl_df.head(10)
# Out:
#                                      id       type  \
# 0  b5759954-f5df-4934-961e-e4f99bc01bf4    CONTROL
# 1  f13b8f3a-28a4-45f6-8f5c-5344412cb3a3  TREATMENT
# 2  eb261cf6-c634-41cc-968b-06df59c49599    CONTROL
# 3  a43a50b5-5177-456e-b2dd-ea45272e3cd2  TREATMENT
# 4  2889f0ae-360b-4419-b304-49da3283b22e  TREATMENT
# 5  78d732c7-ca8a-47c9-b4ef-89e1e564b462  TREATMENT
# 6  39756092-f8a4-443d-aced-20f54e47400d  TREATMENT
# 7  8874fe28-74ad-4900-a290-c0742807812f  TREATMENT
# 8  94802d11-dd96-46d7-840a-ed946019f3fb  TREATMENT
# 9  4538b19b-9e4f-41a7-b341-ec0231594dae    CONTROL
#
#                           experiment_id                           subject_line
# 0  76a8268a-d19b-49ee-9c3d-69cf86f9f0f9                 We take care of you ❤️
# 1  76a8268a-d19b-49ee-9c3d-69cf86f9f0f9                                  asdfa
# 2  14990f86-a9df-4861-a08a-433e9242860d                 We take care of you ❤️
# 3  14990f86-a9df-4861-a08a-433e9242860d  Bra Shopping Nightmares? Not Anymore.
# 4  14990f86-a9df-4861-a08a-433e9242860d    Bra Shopping? We Give You 6 Months.
# 5  14990f86-a9df-4861-a08a-433e9242860d  Bra Shopping Nightmares? Not Anymore.
# 6  2f285599-4ffa-4ded-9eb4-2d9501ce4779    Bra Shopping? We Give You 6 Months.
# 7  14990f86-a9df-4861-a08a-433e9242860d     Your New Bra. 6 Months to Love It.
# 8  2f285599-4ffa-4ded-9eb4-2d9501ce4779  Bra Shopping Nightmares? Not Anymore.
# 9  2f285599-4ffa-4ded-9eb4-2d9501ce4779                 We take care of you ❤️

# %%
from features.subject_line_features import extract_subject_line_features

extract_subject_line_features(sbl_df.head(10),
                              "/Users/broniy/Desktop/creative/prompts/subjectline_prompt.txt",
                              output_path="/Users/broniy/Desktop/creative/outputs/sbl_results.csv")
# Out:
# Analyzing 10 subject lines with gpt-4o...
# Categorizing: 100%|██████████| 10/10 [00:14<00:00,  1.50s/it]
# Results:
#   Successful: 10/10
#   Errors: 0/10
#
# Results saved to: /Users/broniy/Desktop/creative/outputs/sbl_results.csv
#                                      id  \
# 0  b5759954-f5df-4934-961e-e4f99bc01bf4
# 1  f13b8f3a-28a4-45f6-8f5c-5344412cb3a3
# 2  eb261cf6-c634-41cc-968b-06df59c49599
# 3  a43a50b5-5177-456e-b2dd-ea45272e3cd2
# 4  2889f0ae-360b-4419-b304-49da3283b22e
# 5  78d732c7-ca8a-47c9-b4ef-89e1e564b462
# 6  39756092-f8a4-443d-aced-20f54e47400d
# 7  8874fe28-74ad-4900-a290-c0742807812f
# 8  94802d11-dd96-46d7-840a-ed946019f3fb
# 9  4538b19b-9e4f-41a7-b341-ec0231594dae
#
#                             subject_line              category
# 0                 We take care of you ❤️      Emotional appeal
# 1                                  asdfa   Conversational tone
# 2                 We take care of you ❤️      Emotional appeal
# 3  Bra Shopping Nightmares? Not Anymore.      Problem–solution
# 4    Bra Shopping? We Give You 6 Months.  Signature repetition
# 5  Bra Shopping Nightmares? Not Anymore.      Problem–solution
# 6    Bra Shopping? We Give You 6 Months.  Signature repetition
# 7     Your New Bra. 6 Months to Love It.  Signature repetition
# 8  Bra Shopping Nightmares? Not Anymore.      Problem–solution
# 9                 We take care of you ❤️      Emotional appeal
