# %%
import sys
import pandas as pd
sys.path.append('/Users/broniy/Desktop/creative')
# %load_ext autoreload
# %autoreload 2

# %%
from creative_data_fetcher import download_subject_lines

download_subject_lines("fah883amamcdh9393", "../data/subject_lines.csv")
# Out:
# ✅ Connected to the database successfully.
# /Users/broniy/Desktop/creative/creative_data_fetcher.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
# 📁 Query results saved to: ../data/subject_lines.csv

# %%
from dataset import create_dataset

df = create_dataset(
    "/Users/broniy/Desktop/creative/data/creative_links.csv",
    "/Users/broniy/Desktop/creative/data/subject_lines.csv",
    "/Users/broniy/Desktop/creative/data/dataset.csv"
)

df
# Out:
#                                        id type_creative  \
# 0    b5759954-f5df-4934-961e-e4f99bc01bf4       CONTROL
# 1    f13b8f3a-28a4-45f6-8f5c-5344412cb3a3     TREATMENT
# 2    eb261cf6-c634-41cc-968b-06df59c49599       CONTROL
# 3    a43a50b5-5177-456e-b2dd-ea45272e3cd2     TREATMENT
# 4    2889f0ae-360b-4419-b304-49da3283b22e     TREATMENT
# ..                                    ...           ...
# 281  d33d584d-60a7-4b9d-8993-3d1b6786bc2d     TREATMENT
# 282  4eac4d70-7312-4a8a-8e8b-1f71747e0ec9       CONTROL
# 283  0dd3bab1-19bb-472b-93cd-038103dde79e     TREATMENT
# 284  637fdd90-26ed-42aa-affd-b27e5955b4a4     TREATMENT
# 285  c23f8cfd-1185-4513-aecf-a6f6eb0c3816       CONTROL
#
#                    experiment_id_creative  \
# 0    76a8268a-d19b-49ee-9c3d-69cf86f9f0f9
# 1    76a8268a-d19b-49ee-9c3d-69cf86f9f0f9
# 2    14990f86-a9df-4861-a08a-433e9242860d
# 3    14990f86-a9df-4861-a08a-433e9242860d
# 4    14990f86-a9df-4861-a08a-433e9242860d
# ...
